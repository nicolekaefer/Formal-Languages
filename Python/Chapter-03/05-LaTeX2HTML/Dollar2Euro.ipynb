# %%
from IPython.display import HTML
HTML(open('../../style.css').read())

# %%
with open('dollars.txt') as f:
    data = f.read()

# %%
print(data)

# %%
outfile = open('dollars.txt', 'w')

# %%
tokens = [ 'DOLLAR_NUMBER', #r'0|[1-9][0-9]*.[0-9][0-9]\$'
          'EVERY_OTHER_CHAR' #r'.|\n'
]

# %%
def t_DOLLAR_NUMBER(t):
    r'0|[1-9]+([.,][0-9]+)?\s*\$'
    print(dollar_to_euro(float(t.value[:-1].replace('.', '.'))), end='')
    return

# %%
def t_EVERY_OTHER_CHAR(t):
    r'.|\n'
    print(t.value, end='')

# %%
def write_euro(d):
    outfile.write(d*0.85 + '€\n')

# %%
def dollar_to_euro():
    euros = round()

# %% [markdown]
# zwei Token, zwei RegExp, zwei Funktionen
